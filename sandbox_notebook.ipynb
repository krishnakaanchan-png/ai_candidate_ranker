# %% [markdown]
# # FitFinderAi - Redrob Hackathon Sandbox
# This notebook acts as the verifiable execution sandbox. It will install dependencies, run the pre-computation on a small candidate sample, and execute the final ranking.

# %%
# !git clone https://github.com/krishnakaanchan-png/ai_candidate_ranker.git
# %cd ai_candidate_ranker
# !pip install -r requirements.txt

# %% [markdown]
# ## 1. Run Pre-computation
# We simulate Phase 1 by running the embedding generator on the small `sample_candidates.json` provided.

# %%
# !python precompute.py --candidates ../sample_candidates.json --out_dir .

# %% [markdown]
# ## 2. Execute Ranking
# We simulate Stage 3 execution by performing the hybrid semantic search.

# %%
# !python rank.py --candidates ../sample_candidates.json --out team_FitFinderAi.csv
# !head -n 10 team_FitFinderAi.csv
